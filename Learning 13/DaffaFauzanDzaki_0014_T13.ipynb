# %%
# !pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.5 MB ? eta -:--:--
#    - -------------------------------------- 0.5/11.5 MB 1.2 MB/s eta 0:00:10
#    -- ------------------------------------- 0.8/11.5 MB 1.1 MB/s eta 0:00:10
#    -- ------------------------------------- 0.8/11.5 MB 1.1 MB/s eta 0:00:10
#    --- ------------------------------------ 1.0/11.5 MB 1.1 MB/s eta 0:00:10
#    ---- ----------------------------------- 1.3/11.5 MB 1.0 MB/s eta 0:00:10
#    ----- ---------------------------------- 1.6/11.5 MB 1.0 MB/s eta 0:00:10
#    ------ --------------------------------- 1.8/11.5 MB 1.0 MB/s eta 0:00:10
#    ------ --------------------------------- 1.8/11.5 MB 1.0 MB/s eta 0:00:10
#    ------- -------------------------------- 2.1/11.5 MB 994.4 kB/s eta 0:00:10
# ...

# %%
import pandas as pd
from sklearn.preprocessing import StandarScaler

# !pip install SimpSOM
import SimpSOM as sps
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 2
#       1 import pandas as pd
# ----> 2 from sklearn.preprocessing import StandarScaler
#       4 get_ipython().system('pip install SimpSOM')
#       5 import SimpSOM as sps
#
# ModuleNotFoundError: No module named 'sklearn'
